# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shaelyn Ochoa**
# _Data Scientist_

# %% [markdown]
# ### I am interested in data science because I enjoy solving problems with data. Learning more about data science would also allow me to grow my current analytics skill set.

# %% [markdown]
# The code below will multiply 2 by 5.

# %%
2*5
# Out:
# 10

# %% [markdown]
# - Steps to become a data scientist
#     * Step 1: Earn a Bachelors Degree.
#     * Step 2: Learn Relevant Programming Languages.
#     * Step 3: Learn Related Skills.
#     * Step 4: Earn Certifications.
#     * Step 5: Internships.
#     * Step 6: Data Science Entry-Level Jobs.
#     https://brainstation.io/career-guides/how-to-become-a-data-scientist
#
# 1. Steps to become a data engineer
#     1. Develop your data engineering skills. Learn the fundamentals of cloud computing, coding skills, and database design as a starting point for a career in data science.
#     2. Get certified.
#     3. Build a portfolio of data engineering projects.
#     4. Start with an entry-level position.
#     https://www.coursera.org/articles/what-does-a-data-engineer-do-and-how-do-i-become-one
